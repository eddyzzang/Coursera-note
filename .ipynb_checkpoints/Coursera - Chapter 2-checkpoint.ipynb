# %% [markdown]
# ## Gradient Descent with multiple variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Feature Scaling
# - Gradient descent가 더 빠르게 수행하게 만드려면 scaling 을 해주어야 한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 예를 들면,

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 적절한 Learning rate 찾기
# - Gradient descent를 여러번 돌렸을 때 Cost Function이 줄어든다면 최저점을 잘찾고있다는 뜻
# - 또한 적당한 학습률을 찾아야 빠르고 정확하게 minimum을 찾을 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 학습률이 너무 작으면 최저점 찾는게 오래걸리고
#
# 학습률이 너무 크다면 최저점을 못찾을 수 있다.

# %% [markdown]
# ## Normal Equation
# - 지금까지 지금까지 선형회귀에 사용했던 알고리즘은 gradient descent였고, J(θ)를 최소화 화기위한 것이였습니다. 수 차례에 걸쳐 알고리즘을 사용했고, gradient descent를 여러 번 반복하고 나면, 최소값으로 수렴하였습니다. 이와는 반대로, normal equation은 θ를 분석적으로 구하는 방법입니다. 그래서, 여러번 알고리즘을 돌릴 필요 없이, θ의 최적의 값을 한 번에 구합니다. 즉 한 번의 실행으로 최적의 값을 구합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# normal equation 은 Scaling이 필요없다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 역행렬이 없는이유

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 출처: https://www.coursera.org/learn/machine-learning
